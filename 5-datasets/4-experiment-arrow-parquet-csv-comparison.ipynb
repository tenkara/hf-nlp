# %% [markdown]
# ### Compare performance of Arrow, CSV and Parquet

# %%
import pyarrow.parquet as pq
import pyarrow as pa
import pandas as pd
import numpy as np
import os
import psutil

# %% [markdown]
# ##### 1. Load and prepare data

# %%
# Read covid data from github
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 316650      ZWE    Africa     Zimbabwe  2023-06-03     265139.0       32.0
# 316651      ZWE    Africa     Zimbabwe  2023-06-04     265139.0        0.0
# 316652      ZWE    Africa     Zimbabwe  2023-06-05     265139.0        0.0
# 316653      ZWE    Africa     Zimbabwe  2023-06-06     265139.0        0.0
# 316654      ZWE    Africa     Zimbabwe  2023-06-07     265139.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 316650              21.000        5695.0         0.0                0.429
# 316651              16.571        5695.0         0.0                0.286
# 316652              15.571        5695.0         0.0                0.000
# 316653              15.571        5695.0         0.0                0.000
# 316654               9.286        5695.0         0.0                0.000
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 316650  ...          30.7                  36.791                         1.7
# 316651  ...          30.7                  36.791                         1.7
# 316652  ...          30.7                  36.791                         1.7
# 316653  ...          30.7                  36.791                         1.7
# 316654  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 316650            61.49                    0.571  16320539.0
# 316651            61.49                    0.571  16320539.0
# 316652            61.49                    0.571  16320539.0
# 316653            61.49                    0.571  16320539.0
# 316654            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 316650                                   NaN                          NaN
# 316651                                   NaN                          NaN
# 316652                                   NaN                          NaN
# 316653                                   NaN                          NaN
# 316654                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 316650               NaN                                      NaN
# 316651               NaN                                      NaN
# 316652               NaN                                      NaN
# 316653               NaN                                      NaN
# 316654               NaN                                      NaN
#
# [316655 rows x 67 columns]

# %%
df_copy = df.copy()
df_copy
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 316650      ZWE    Africa     Zimbabwe  2023-06-03     265139.0       32.0
# 316651      ZWE    Africa     Zimbabwe  2023-06-04     265139.0        0.0
# 316652      ZWE    Africa     Zimbabwe  2023-06-05     265139.0        0.0
# 316653      ZWE    Africa     Zimbabwe  2023-06-06     265139.0        0.0
# 316654      ZWE    Africa     Zimbabwe  2023-06-07     265139.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 316650              21.000        5695.0         0.0                0.429
# 316651              16.571        5695.0         0.0                0.286
# 316652              15.571        5695.0         0.0                0.000
# 316653              15.571        5695.0         0.0                0.000
# 316654               9.286        5695.0         0.0                0.000
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 316650  ...          30.7                  36.791                         1.7
# 316651  ...          30.7                  36.791                         1.7
# 316652  ...          30.7                  36.791                         1.7
# 316653  ...          30.7                  36.791                         1.7
# 316654  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 316650            61.49                    0.571  16320539.0
# 316651            61.49                    0.571  16320539.0
# 316652            61.49                    0.571  16320539.0
# 316653            61.49                    0.571  16320539.0
# 316654            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 316650                                   NaN                          NaN
# 316651                                   NaN                          NaN
# 316652                                   NaN                          NaN
# 316653                                   NaN                          NaN
# 316654                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 316650               NaN                                      NaN
# 316651               NaN                                      NaN
# 316652               NaN                                      NaN
# 316653               NaN                                      NaN
# 316654               NaN                                      NaN
#
# [316655 rows x 67 columns]

# %%
# show all object columns
df_copy.select_dtypes(include=['object']).columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'tests_units'], dtype='object')

# %%
# convert object columns to category
for col in df_copy.select_dtypes(include=['object']).columns:
    df_copy[col] = df_copy[col].astype('category')

# show all object columns
df_copy.select_dtypes(include=['object']).columns
# Out:
# Index([], dtype='object')

# %%
# show all category columns
df_copy.select_dtypes(include=['category']).columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'tests_units'], dtype='object')

# %%
# null values in category columns
df_copy.select_dtypes(include=['category']).isnull().sum()
# Out:
# iso_code            0
# continent       15042
# location            0
# date                0
# tests_units    209867
# dtype: int64

# %%
# sample category column with null values
df_copy['continent'].sample(10)
# Out:
# 94610      Europe
# 5102      Oceania
# 162268     Europe
# 165543     Africa
# 212884       Asia
# 276852       Asia
# 36710      Africa
# 195513    Oceania
# 226168     Europe
# 199074     Africa
# Name: continent, dtype: category
# Categories (6, object): ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# %%
# sample rows with null values
df_copy[df_copy['continent'].isnull()].sample(10)
# Out:
#         iso_code continent             location        date  total_cases  \
# 88578   OWID_EUR       NaN               Europe  2022-10-09  230099816.0
# 88396   OWID_EUR       NaN               Europe  2022-04-10  184860574.0
# 263237  OWID_SAM       NaN        South America  2020-10-15    8824805.0
# 203350  OWID_NAM       NaN        North America  2022-12-06  117380642.0
# 15221   OWID_ASI       NaN                 Asia  2020-07-13    2972365.0
# 15440   OWID_ASI       NaN                 Asia  2021-02-17   24223499.0
# 160257  OWID_LMC       NaN  Lower middle income  2020-04-06      80928.0
# 263249  OWID_SAM       NaN        South America  2020-10-27    9441337.0
# 203438  OWID_NAM       NaN        North America  2023-03-04  122820239.0
# 15833   OWID_ASI       NaN                 Asia  2022-03-17  130404440.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 88578    193076.0          275993.143     1952773.0       517.0
# 88396    426109.0          529382.714     1826630.0      1197.0
# 263237    38808.0           49087.429      333642.0      1120.0
# 203350     3775.0           51820.714     1536035.0        18.0
# 15221     56510.0           54942.000       70386.0      1352.0
# 15440     68105.0           64868.000      389139.0       838.0
# 160257     4569.0            4634.571        4743.0       271.0
# 263249    41688.0           50875.143      348723.0       912.0
# 203438   240873.0           38359.429     1583160.0      2374.0
# 15833    947192.0          871940.571     1384496.0      1743.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 88578               715.286  ...           NaN                     NaN
# 88396              1469.714  ...           NaN                     NaN
# 263237             1355.714  ...           NaN                     NaN
# 203350              318.429  ...           NaN                     NaN
# 15221              1148.286  ...           NaN                     NaN
# 15440               858.857  ...           NaN                     NaN
# 160257              244.571  ...           NaN                     NaN
# 263249             1186.857  ...           NaN                     NaN
# 203438              360.286  ...           NaN                     NaN
# 15833              1742.143  ...           NaN                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 88578                          NaN              NaN                      NaN
# 88396                          NaN              NaN                      NaN
# 263237                         NaN              NaN                      NaN
# 203350                         NaN              NaN                      NaN
# 15221                          NaN              NaN                      NaN
# 15440                          NaN              NaN                      NaN
# 160257                         NaN              NaN                      NaN
# 263249                         NaN              NaN                      NaN
# 203438                         NaN              NaN                      NaN
# 15833                          NaN              NaN                      NaN
#
#           population  excess_mortality_cumulative_absolute  \
# 88578   7.448078e+08                                   NaN
# 88396   7.448078e+08                                   NaN
# 263237  4.368167e+08                                   NaN
# 203350  6.003237e+08                                   NaN
# 15221   4.721383e+09                                   NaN
# 15440   4.721383e+09                                   NaN
# 160257  3.432097e+09                                   NaN
# 263249  4.368167e+08                                   NaN
# 203438  6.003237e+08                                   NaN
# 15833   4.721383e+09                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 88578                           NaN               NaN
# 88396                           NaN               NaN
# 263237                          NaN               NaN
# 203350                          NaN               NaN
# 15221                           NaN               NaN
# 15440                           NaN               NaN
# 160257                          NaN               NaN
# 263249                          NaN               NaN
# 203438                          NaN               NaN
# 15833                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 88578                                       NaN
# 88396                                       NaN
# 263237                                      NaN
# 203350                                      NaN
# 15221                                       NaN
# 15440                                       NaN
# 160257                                      NaN
# 263249                                      NaN
# 203438                                      NaN
# 15833                                       NaN
#
# [10 rows x 67 columns]

# %%
# select distinct values from the location column
df_copy['location'].unique()
# Out:
# ['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa', ..., 'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe']
# Length: 255
# Categories (255, object): ['Afghanistan', 'Africa', 'Albania', 'Algeria', ..., 'World', 'Yemen', 'Zambia', 'Zimbabwe']

# %%
# select distinct values from the continent column
df_copy['continent'].unique()
# Out:
# ['Asia', NaN, 'Europe', 'Africa', 'Oceania', 'North America', 'South America']
# Categories (6, object): ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# %%
# select distinct values from the tests_units column
df_copy['tests_units'].unique()
# Out:
# [NaN, 'tests performed', 'units unclear', 'samples tested', 'people tested']
# Categories (4, object): ['people tested', 'samples tested', 'tests performed', 'units unclear']

# %%
# drop test_units and continent columns
df_copy.drop(['tests_units', 'continent'], axis=1, inplace=True)

# %%
df_copy
# Out:
#        iso_code     location        date  total_cases  new_cases  \
# 0           AFG  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG  Afghanistan  2020-01-07          NaN        0.0
# ...         ...          ...         ...          ...        ...
# 316650      ZWE     Zimbabwe  2023-06-03     265139.0       32.0
# 316651      ZWE     Zimbabwe  2023-06-04     265139.0        0.0
# 316652      ZWE     Zimbabwe  2023-06-05     265139.0        0.0
# 316653      ZWE     Zimbabwe  2023-06-06     265139.0        0.0
# 316654      ZWE     Zimbabwe  2023-06-07     265139.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 316650              21.000        5695.0         0.0                0.429
# 316651              16.571        5695.0         0.0                0.286
# 316652              15.571        5695.0         0.0                0.000
# 316653              15.571        5695.0         0.0                0.000
# 316654               9.286        5695.0         0.0                0.000
#
#         total_cases_per_million  ...  male_smokers  handwashing_facilities  \
# 0                           NaN  ...           NaN                  37.746
# 1                           NaN  ...           NaN                  37.746
# 2                           NaN  ...           NaN                  37.746
# 3                           NaN  ...           NaN                  37.746
# 4                           NaN  ...           NaN                  37.746
# ...                         ...  ...           ...                     ...
# 316650                16245.726  ...          30.7                  36.791
# 316651                16245.726  ...          30.7                  36.791
# 316652                16245.726  ...          30.7                  36.791
# 316653                16245.726  ...          30.7                  36.791
# 316654                16245.726  ...          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 316650                         1.7            61.49                    0.571
# 316651                         1.7            61.49                    0.571
# 316652                         1.7            61.49                    0.571
# 316653                         1.7            61.49                    0.571
# 316654                         1.7            61.49                    0.571
#
#         population  excess_mortality_cumulative_absolute  \
# 0       41128772.0                                   NaN
# 1       41128772.0                                   NaN
# 2       41128772.0                                   NaN
# 3       41128772.0                                   NaN
# 4       41128772.0                                   NaN
# ...            ...                                   ...
# 316650  16320539.0                                   NaN
# 316651  16320539.0                                   NaN
# 316652  16320539.0                                   NaN
# 316653  16320539.0                                   NaN
# 316654  16320539.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 316650                          NaN               NaN
# 316651                          NaN               NaN
# 316652                          NaN               NaN
# 316653                          NaN               NaN
# 316654                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 316650                                      NaN
# 316651                                      NaN
# 316652                                      NaN
# 316653                                      NaN
# 316654                                      NaN
#
# [316655 rows x 65 columns]

# %%
# convert object columns to category
for col in df_copy.select_dtypes(include=['object']).columns:
    df_copy[col] = df_copy[col].astype('category')

# show all object columns
df_copy.select_dtypes(include=['object']).columns

# show all category columns

# %%
# show data types
df_copy.dtypes
# Out:
# iso_code                                   category
# location                                   category
# date                                       category
# total_cases                                 float64
# new_cases                                   float64
#                                              ...
# population                                  float64
# excess_mortality_cumulative_absolute        float64
# excess_mortality_cumulative                 float64
# excess_mortality                            float64
# excess_mortality_cumulative_per_million     float64
# Length: 65, dtype: object

# %%
# increase dataset to 1 million rows and reset index
df_copy = df_copy.sample(n=1000000, replace=True).reset_index(drop=True)
df_copy
# Out:
#        iso_code                  location        date  total_cases  new_cases  \
# 0           TCA  Turks and Caicos Islands  2022-01-07       3562.0        0.0
# 1           JPN                     Japan  2020-12-07     162067.0     1969.0
# 2           PHL               Philippines  2021-09-06    2103296.0    22380.0
# 3           CAN                    Canada  2022-11-13    4380999.0        0.0
# 4           BMU                   Bermuda  2022-11-11      18428.0        0.0
# ...         ...                       ...         ...          ...        ...
# 999995      NZL               New Zealand  2020-06-17       1156.0        0.0
# 999996      POL                    Poland  2021-01-19    1446149.0     4835.0
# 999997      MRT                Mauritania  2023-01-21      63435.0        0.0
# 999998      PER                      Peru  2022-10-03    4145048.0      632.0
# 999999      AUT                   Austria  2020-12-30     349692.0     2107.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                   39.857          26.0         0.0                0.000
# 1                 2186.714        2335.0        20.0               30.857
# 2                18180.857       34337.0       103.0              143.857
# 3                 2627.857       46537.0         0.0               49.143
# 4                    0.000         149.0         0.0                0.000
# ...                    ...           ...         ...                  ...
# 999995               0.286          22.0         0.0                0.000
# 999996            6836.714       33777.0       291.0              300.286
# 999997               0.000         997.0         0.0                0.000
# 999998             596.286      216578.0         3.0               15.000
# 999999            1918.286        7296.0        89.0               87.857
#
#         total_cases_per_million  ...  male_smokers  handwashing_facilities  \
# 0                     77898.788  ...           NaN                     NaN
# 1                      1307.501  ...          33.7                     NaN
# 2                     18201.056  ...          40.8                  78.463
# 3                    113927.332  ...          16.6                     NaN
# 4                    287009.205  ...           NaN                     NaN
# ...                         ...  ...           ...                     ...
# 999995                  222.938  ...          17.2                     NaN
# 999996                36283.307  ...          33.1                     NaN
# 999997                13393.802  ...           NaN                  15.950
# 999998               121735.629  ...           NaN                     NaN
# 999999                39117.112  ...          30.9                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              NaN            80.22                      NaN
# 1                            13.05            84.63                    0.919
# 2                             1.00            71.23                    0.718
# 3                             2.50            82.43                    0.929
# 4                              NaN            82.59                      NaN
# ...                            ...              ...                      ...
# 999995                        2.61            82.29                    0.931
# 999996                        6.62            78.73                    0.880
# 999997                         NaN            64.92                    0.546
# 999998                        1.60            76.74                    0.777
# 999999                        7.37            81.54                    0.922
#
#          population  excess_mortality_cumulative_absolute  \
# 0           45726.0                                   NaN
# 1       123951696.0                                   NaN
# 2       115559008.0                                   NaN
# 3        38454328.0                              44146.23
# 4           64207.0                                   NaN
# ...             ...                                   ...
# 999995    5185289.0                                   NaN
# 999996   39857144.0                                   NaN
# 999997    4736146.0                                   NaN
# 999998   34049588.0                                   NaN
# 999999    8939617.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                              5.13              7.94
# 4                               NaN               NaN
# ...                             ...               ...
# 999995                          NaN               NaN
# 999996                          NaN               NaN
# 999997                          NaN               NaN
# 999998                          NaN               NaN
# 999999                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                     1148.0172
# 4                                           NaN
# ...                                         ...
# 999995                                      NaN
# 999996                                      NaN
# 999997                                      NaN
# 999998                                      NaN
# 999999                                      NaN
#
# [1000000 rows x 65 columns]

# %%
# update sample number column with index
df_copy["Sample Number"] = df_copy.index
df_copy
# Out:
#        iso_code                  location        date  total_cases  new_cases  \
# 0           TCA  Turks and Caicos Islands  2022-01-07       3562.0        0.0
# 1           JPN                     Japan  2020-12-07     162067.0     1969.0
# 2           PHL               Philippines  2021-09-06    2103296.0    22380.0
# 3           CAN                    Canada  2022-11-13    4380999.0        0.0
# 4           BMU                   Bermuda  2022-11-11      18428.0        0.0
# ...         ...                       ...         ...          ...        ...
# 999995      NZL               New Zealand  2020-06-17       1156.0        0.0
# 999996      POL                    Poland  2021-01-19    1446149.0     4835.0
# 999997      MRT                Mauritania  2023-01-21      63435.0        0.0
# 999998      PER                      Peru  2022-10-03    4145048.0      632.0
# 999999      AUT                   Austria  2020-12-30     349692.0     2107.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                   39.857          26.0         0.0                0.000
# 1                 2186.714        2335.0        20.0               30.857
# 2                18180.857       34337.0       103.0              143.857
# 3                 2627.857       46537.0         0.0               49.143
# 4                    0.000         149.0         0.0                0.000
# ...                    ...           ...         ...                  ...
# 999995               0.286          22.0         0.0                0.000
# 999996            6836.714       33777.0       291.0              300.286
# 999997               0.000         997.0         0.0                0.000
# 999998             596.286      216578.0         3.0               15.000
# 999999            1918.286        7296.0        89.0               87.857
#
#         total_cases_per_million  ...  handwashing_facilities  \
# 0                     77898.788  ...                     NaN
# 1                      1307.501  ...                     NaN
# 2                     18201.056  ...                  78.463
# 3                    113927.332  ...                     NaN
# 4                    287009.205  ...                     NaN
# ...                         ...  ...                     ...
# 999995                  222.938  ...                     NaN
# 999996                36283.307  ...                     NaN
# 999997                13393.802  ...                  15.950
# 999998               121735.629  ...                     NaN
# 999999                39117.112  ...                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              NaN            80.22                      NaN
# 1                            13.05            84.63                    0.919
# 2                             1.00            71.23                    0.718
# 3                             2.50            82.43                    0.929
# 4                              NaN            82.59                      NaN
# ...                            ...              ...                      ...
# 999995                        2.61            82.29                    0.931
# 999996                        6.62            78.73                    0.880
# 999997                         NaN            64.92                    0.546
# 999998                        1.60            76.74                    0.777
# 999999                        7.37            81.54                    0.922
#
#          population  excess_mortality_cumulative_absolute  \
# 0           45726.0                                   NaN
# 1       123951696.0                                   NaN
# 2       115559008.0                                   NaN
# 3        38454328.0                              44146.23
# 4           64207.0                                   NaN
# ...             ...                                   ...
# 999995    5185289.0                                   NaN
# 999996   39857144.0                                   NaN
# 999997    4736146.0                                   NaN
# 999998   34049588.0                                   NaN
# 999999    8939617.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                              5.13              7.94
# 4                               NaN               NaN
# ...                             ...               ...
# 999995                          NaN               NaN
# 999996                          NaN               NaN
# 999997                          NaN               NaN
# 999998                          NaN               NaN
# 999999                          NaN               NaN
#
#         excess_mortality_cumulative_per_million  Sample Number
# 0                                           NaN              0
# 1                                           NaN              1
# 2                                           NaN              2
# 3                                     1148.0172              3
# 4                                           NaN              4
# ...                                         ...            ...
# 999995                                      NaN         999995
# 999996                                      NaN         999996
# 999997                                      NaN         999997
# 999998                                      NaN         999998
# 999999                                      NaN         999999
#
# [1000000 rows x 66 columns]

# %%
# show missing values in dataset
df_copy.isnull().sum()
# Out:
# iso_code                                        0
# location                                        0
# date                                            0
# total_cases                                114876
# new_cases                                   27827
#                                             ...
# excess_mortality_cumulative_absolute       965261
# excess_mortality_cumulative                965261
# excess_mortality                           965261
# excess_mortality_cumulative_per_million    965261
# Sample Number                                   0
# Length: 66, dtype: int64

# %%
# fill missing values with 0 for all non-category columns
for col in df_copy.select_dtypes(exclude=['category']).columns:
    df_copy[col] = df_copy[col].fillna(0)

# %%
# show missing values in dataset
df_copy.isnull().sum()
# Out:
# iso_code                                   0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
#                                           ..
# excess_mortality_cumulative_absolute       0
# excess_mortality_cumulative                0
# excess_mortality                           0
# excess_mortality_cumulative_per_million    0
# Sample Number                              0
# Length: 66, dtype: int64

# %%
df_copy
# Out:
#        iso_code                  location        date  total_cases  new_cases  \
# 0           TCA  Turks and Caicos Islands  2022-01-07       3562.0        0.0
# 1           JPN                     Japan  2020-12-07     162067.0     1969.0
# 2           PHL               Philippines  2021-09-06    2103296.0    22380.0
# 3           CAN                    Canada  2022-11-13    4380999.0        0.0
# 4           BMU                   Bermuda  2022-11-11      18428.0        0.0
# ...         ...                       ...         ...          ...        ...
# 999995      NZL               New Zealand  2020-06-17       1156.0        0.0
# 999996      POL                    Poland  2021-01-19    1446149.0     4835.0
# 999997      MRT                Mauritania  2023-01-21      63435.0        0.0
# 999998      PER                      Peru  2022-10-03    4145048.0      632.0
# 999999      AUT                   Austria  2020-12-30     349692.0     2107.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                   39.857          26.0         0.0                0.000
# 1                 2186.714        2335.0        20.0               30.857
# 2                18180.857       34337.0       103.0              143.857
# 3                 2627.857       46537.0         0.0               49.143
# 4                    0.000         149.0         0.0                0.000
# ...                    ...           ...         ...                  ...
# 999995               0.286          22.0         0.0                0.000
# 999996            6836.714       33777.0       291.0              300.286
# 999997               0.000         997.0         0.0                0.000
# 999998             596.286      216578.0         3.0               15.000
# 999999            1918.286        7296.0        89.0               87.857
#
#         total_cases_per_million  ...  handwashing_facilities  \
# 0                     77898.788  ...                   0.000
# 1                      1307.501  ...                   0.000
# 2                     18201.056  ...                  78.463
# 3                    113927.332  ...                   0.000
# 4                    287009.205  ...                   0.000
# ...                         ...  ...                     ...
# 999995                  222.938  ...                   0.000
# 999996                36283.307  ...                   0.000
# 999997                13393.802  ...                  15.950
# 999998               121735.629  ...                   0.000
# 999999                39117.112  ...                   0.000
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.00            80.22                    0.000
# 1                            13.05            84.63                    0.919
# 2                             1.00            71.23                    0.718
# 3                             2.50            82.43                    0.929
# 4                             0.00            82.59                    0.000
# ...                            ...              ...                      ...
# 999995                        2.61            82.29                    0.931
# 999996                        6.62            78.73                    0.880
# 999997                        0.00            64.92                    0.546
# 999998                        1.60            76.74                    0.777
# 999999                        7.37            81.54                    0.922
#
#          population  excess_mortality_cumulative_absolute  \
# 0           45726.0                                  0.00
# 1       123951696.0                                  0.00
# 2       115559008.0                                  0.00
# 3        38454328.0                              44146.23
# 4           64207.0                                  0.00
# ...             ...                                   ...
# 999995    5185289.0                                  0.00
# 999996   39857144.0                                  0.00
# 999997    4736146.0                                  0.00
# 999998   34049588.0                                  0.00
# 999999    8939617.0                                  0.00
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                              0.00              0.00
# 1                              0.00              0.00
# 2                              0.00              0.00
# 3                              5.13              7.94
# 4                              0.00              0.00
# ...                             ...               ...
# 999995                         0.00              0.00
# 999996                         0.00              0.00
# 999997                         0.00              0.00
# 999998                         0.00              0.00
# 999999                         0.00              0.00
#
#         excess_mortality_cumulative_per_million  Sample Number
# 0                                        0.0000              0
# 1                                        0.0000              1
# 2                                        0.0000              2
# 3                                     1148.0172              3
# 4                                        0.0000              4
# ...                                         ...            ...
# 999995                                   0.0000         999995
# 999996                                   0.0000         999996
# 999997                                   0.0000         999997
# 999998                                   0.0000         999998
# 999999                                   0.0000         999999
#
# [1000000 rows x 66 columns]

# %% [markdown]
# #### 1.2 Write to disk

# %%
# write to csv
df_copy.to_csv("../data/covid-data.csv")

# %%
# write to parquet
df.to_parquet("../data/covid-data.parquet")

# %%
# write to arrow
# convert from pandas to arrow
table = pa.Table.from_pandas(df_copy)
# write to arrow file
pq.write_table(table, '../data/covid-data.arrow')
