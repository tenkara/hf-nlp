# %% [markdown]
# ### Compare performance of Arrow, CSV and Parquet

# %%
import pyarrow.parquet as pq
import pyarrow as pa
import pandas as pd
import numpy as np
import os
import psutil

# %% [markdown]
# ##### 1. Load and prepare data

# %%
# Read covid data from github
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 316650      ZWE    Africa     Zimbabwe  2023-06-03     265139.0       32.0
# 316651      ZWE    Africa     Zimbabwe  2023-06-04     265139.0        0.0
# 316652      ZWE    Africa     Zimbabwe  2023-06-05     265139.0        0.0
# 316653      ZWE    Africa     Zimbabwe  2023-06-06     265139.0        0.0
# 316654      ZWE    Africa     Zimbabwe  2023-06-07     265139.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 316650              21.000        5695.0         0.0                0.429
# 316651              16.571        5695.0         0.0                0.286
# 316652              15.571        5695.0         0.0                0.000
# 316653              15.571        5695.0         0.0                0.000
# 316654               9.286        5695.0         0.0                0.000
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 316650  ...          30.7                  36.791                         1.7
# 316651  ...          30.7                  36.791                         1.7
# 316652  ...          30.7                  36.791                         1.7
# 316653  ...          30.7                  36.791                         1.7
# 316654  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 316650            61.49                    0.571  16320539.0
# 316651            61.49                    0.571  16320539.0
# 316652            61.49                    0.571  16320539.0
# 316653            61.49                    0.571  16320539.0
# 316654            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 316650                                   NaN                          NaN
# 316651                                   NaN                          NaN
# 316652                                   NaN                          NaN
# 316653                                   NaN                          NaN
# 316654                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 316650               NaN                                      NaN
# 316651               NaN                                      NaN
# 316652               NaN                                      NaN
# 316653               NaN                                      NaN
# 316654               NaN                                      NaN
#
# [316655 rows x 67 columns]

# %%
df_copy = df.copy()
df_copy
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 316650      ZWE    Africa     Zimbabwe  2023-06-03     265139.0       32.0
# 316651      ZWE    Africa     Zimbabwe  2023-06-04     265139.0        0.0
# 316652      ZWE    Africa     Zimbabwe  2023-06-05     265139.0        0.0
# 316653      ZWE    Africa     Zimbabwe  2023-06-06     265139.0        0.0
# 316654      ZWE    Africa     Zimbabwe  2023-06-07     265139.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 316650              21.000        5695.0         0.0                0.429
# 316651              16.571        5695.0         0.0                0.286
# 316652              15.571        5695.0         0.0                0.000
# 316653              15.571        5695.0         0.0                0.000
# 316654               9.286        5695.0         0.0                0.000
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 316650  ...          30.7                  36.791                         1.7
# 316651  ...          30.7                  36.791                         1.7
# 316652  ...          30.7                  36.791                         1.7
# 316653  ...          30.7                  36.791                         1.7
# 316654  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 316650            61.49                    0.571  16320539.0
# 316651            61.49                    0.571  16320539.0
# 316652            61.49                    0.571  16320539.0
# 316653            61.49                    0.571  16320539.0
# 316654            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 316650                                   NaN                          NaN
# 316651                                   NaN                          NaN
# 316652                                   NaN                          NaN
# 316653                                   NaN                          NaN
# 316654                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 316650               NaN                                      NaN
# 316651               NaN                                      NaN
# 316652               NaN                                      NaN
# 316653               NaN                                      NaN
# 316654               NaN                                      NaN
#
# [316655 rows x 67 columns]

# %%
# show all object columns
df_copy.select_dtypes(include=['object']).columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'tests_units'], dtype='object')

# %%
# convert object columns to category
for col in df_copy.select_dtypes(include=['object']).columns:
    df_copy[col] = df_copy[col].astype('category')

# show all object columns
df_copy.select_dtypes(include=['object']).columns
# Out:
# Index([], dtype='object')

# %%
# show all category columns
df_copy.select_dtypes(include=['category']).columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'tests_units'], dtype='object')

# %%
# convert object columns to category
for col in df_copy.select_dtypes(include=['object']).columns:
    df_copy[col] = df_copy[col].astype('category')

# show all object columns
df_copy.select_dtypes(include=['object']).columns

# show all category columns

# %%
# show data types
df_copy.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# population                                 float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %%
# increase dataset to 1 million rows and reset index
df = df.sample(n=1000000, replace=True).reset_index(drop=True)
df
# Out:
#        iso_code      continent               location        date  \
# 0           HUN         Europe                Hungary  2022-01-12
# 1           LTU         Europe              Lithuania  2020-07-10
# 2           EST         Europe                Estonia  2023-01-01
# 3           HTI  North America                  Haiti  2021-04-27
# 4           PAN  North America                 Panama  2022-08-05
# ...         ...            ...                    ...         ...
# 999995      JPN           Asia                  Japan  2020-03-16
# 999996      AND         Europe                Andorra  2020-03-19
# 999997      BHS  North America                Bahamas  2022-11-08
# 999998      LVA         Europe                 Latvia  2022-09-16
# 999999      STP         Africa  Sao Tome and Principe  2022-08-17
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0         1308877.0     7883.0            5556.857       40083.0        67.0
# 1            1796.0        7.0               5.143          62.0         0.0
# 2          612338.0       44.0              76.000        2853.0         0.0
# 3           13101.0        5.0              12.000         254.0         0.0
# 4          954369.0        0.0             842.286        8425.0         0.0
# ...             ...        ...                 ...           ...         ...
# 999995        814.0       34.0              46.429          27.0         5.0
# 999996         39.0        0.0               5.429           NaN         0.0
# 999997      37419.0        0.0               4.714         833.0         0.0
# 999998     913371.0     1369.0            1066.714        5969.0         4.0
# 999999       6123.0        0.0               0.429          76.0         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 0                    69.143  ...          34.8                     NaN
# 1                     0.000  ...          38.0                     NaN
# 2                     2.286  ...          39.3                     NaN
# 3                     0.000  ...          23.1                  22.863
# 4                     1.857  ...           9.9                     NaN
# ...                     ...  ...           ...                     ...
# 999995                2.429  ...          33.7                     NaN
# 999996                0.000  ...          37.8                     NaN
# 999997                0.000  ...          20.4                     NaN
# 999998                1.714  ...          51.0                     NaN
# 999999                0.000  ...           NaN                  41.340
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             7.02            76.88                    0.854
# 1                             6.56            75.93                    0.882
# 2                             4.69            78.74                    0.892
# 3                             0.70            64.00                    0.510
# 4                             2.30            78.51                    0.815
# ...                            ...              ...                      ...
# 999995                       13.05            84.63                    0.919
# 999996                         NaN            83.73                    0.868
# 999997                        2.90            73.92                    0.814
# 999998                        5.57            75.29                    0.866
# 999999                        2.90            70.39                    0.625
#
#          population  excess_mortality_cumulative_absolute  \
# 0         9967304.0                                   NaN
# 1         2750058.0                                   NaN
# 2         1326064.0                              4739.699
# 3        11585003.0                                   NaN
# 4         4408582.0                                   NaN
# ...             ...                                   ...
# 999995  123951696.0                                   NaN
# 999996      79843.0                                   NaN
# 999997     409989.0                                   NaN
# 999998    1850654.0                                   NaN
# 999999     227393.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                             10.03             30.86
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 999995                          NaN               NaN
# 999996                          NaN               NaN
# 999997                          NaN               NaN
# 999998                          NaN               NaN
# 999999                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                     3583.1782
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 999995                                      NaN
# 999996                                      NaN
# 999997                                      NaN
# 999998                                      NaN
# 999999                                      NaN
#
# [1000000 rows x 67 columns]

# %%
# update sample number column with index
df["Sample Number"] = df.index
df
# Out:
#        iso_code      continent               location        date  \
# 0           HUN         Europe                Hungary  2022-01-12
# 1           LTU         Europe              Lithuania  2020-07-10
# 2           EST         Europe                Estonia  2023-01-01
# 3           HTI  North America                  Haiti  2021-04-27
# 4           PAN  North America                 Panama  2022-08-05
# ...         ...            ...                    ...         ...
# 999995      JPN           Asia                  Japan  2020-03-16
# 999996      AND         Europe                Andorra  2020-03-19
# 999997      BHS  North America                Bahamas  2022-11-08
# 999998      LVA         Europe                 Latvia  2022-09-16
# 999999      STP         Africa  Sao Tome and Principe  2022-08-17
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0         1308877.0     7883.0            5556.857       40083.0        67.0
# 1            1796.0        7.0               5.143          62.0         0.0
# 2          612338.0       44.0              76.000        2853.0         0.0
# 3           13101.0        5.0              12.000         254.0         0.0
# 4          954369.0        0.0             842.286        8425.0         0.0
# ...             ...        ...                 ...           ...         ...
# 999995        814.0       34.0              46.429          27.0         5.0
# 999996         39.0        0.0               5.429           NaN         0.0
# 999997      37419.0        0.0               4.714         833.0         0.0
# 999998     913371.0     1369.0            1066.714        5969.0         4.0
# 999999       6123.0        0.0               0.429          76.0         0.0
#
#         new_deaths_smoothed  ...  handwashing_facilities  \
# 0                    69.143  ...                     NaN
# 1                     0.000  ...                     NaN
# 2                     2.286  ...                     NaN
# 3                     0.000  ...                  22.863
# 4                     1.857  ...                     NaN
# ...                     ...  ...                     ...
# 999995                2.429  ...                     NaN
# 999996                0.000  ...                     NaN
# 999997                0.000  ...                     NaN
# 999998                1.714  ...                     NaN
# 999999                0.000  ...                  41.340
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             7.02            76.88                    0.854
# 1                             6.56            75.93                    0.882
# 2                             4.69            78.74                    0.892
# 3                             0.70            64.00                    0.510
# 4                             2.30            78.51                    0.815
# ...                            ...              ...                      ...
# 999995                       13.05            84.63                    0.919
# 999996                         NaN            83.73                    0.868
# 999997                        2.90            73.92                    0.814
# 999998                        5.57            75.29                    0.866
# 999999                        2.90            70.39                    0.625
#
#          population  excess_mortality_cumulative_absolute  \
# 0         9967304.0                                   NaN
# 1         2750058.0                                   NaN
# 2         1326064.0                              4739.699
# 3        11585003.0                                   NaN
# 4         4408582.0                                   NaN
# ...             ...                                   ...
# 999995  123951696.0                                   NaN
# 999996      79843.0                                   NaN
# 999997     409989.0                                   NaN
# 999998    1850654.0                                   NaN
# 999999     227393.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                             10.03             30.86
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 999995                          NaN               NaN
# 999996                          NaN               NaN
# 999997                          NaN               NaN
# 999998                          NaN               NaN
# 999999                          NaN               NaN
#
#         excess_mortality_cumulative_per_million  Sample Number
# 0                                           NaN              0
# 1                                           NaN              1
# 2                                     3583.1782              2
# 3                                           NaN              3
# 4                                           NaN              4
# ...                                         ...            ...
# 999995                                      NaN         999995
# 999996                                      NaN         999996
# 999997                                      NaN         999997
# 999998                                      NaN         999998
# 999999                                      NaN         999999
#
# [1000000 rows x 68 columns]

# %%
# show missing values in dataset
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   47254
# location                                        0
# date                                            0
# total_cases                                113780
#                                             ...
# excess_mortality_cumulative_absolute       965193
# excess_mortality_cumulative                965193
# excess_mortality                           965193
# excess_mortality_cumulative_per_million    965193
# Sample Number                                   0
# Length: 68, dtype: int64

# %%
# fill missing values with 0
df = df.fillna(0)

# %%
# show missing values in dataset
df.isnull().sum()
# Out:
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
#                                           ..
# excess_mortality_cumulative_absolute       0
# excess_mortality_cumulative                0
# excess_mortality                           0
# excess_mortality_cumulative_per_million    0
# Sample Number                              0
# Length: 68, dtype: int64

# %%
df
# Out:
#        iso_code      continent               location        date  \
# 0           HUN         Europe                Hungary  2022-01-12
# 1           LTU         Europe              Lithuania  2020-07-10
# 2           EST         Europe                Estonia  2023-01-01
# 3           HTI  North America                  Haiti  2021-04-27
# 4           PAN  North America                 Panama  2022-08-05
# ...         ...            ...                    ...         ...
# 999995      JPN           Asia                  Japan  2020-03-16
# 999996      AND         Europe                Andorra  2020-03-19
# 999997      BHS  North America                Bahamas  2022-11-08
# 999998      LVA         Europe                 Latvia  2022-09-16
# 999999      STP         Africa  Sao Tome and Principe  2022-08-17
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0         1308877.0     7883.0            5556.857       40083.0        67.0
# 1            1796.0        7.0               5.143          62.0         0.0
# 2          612338.0       44.0              76.000        2853.0         0.0
# 3           13101.0        5.0              12.000         254.0         0.0
# 4          954369.0        0.0             842.286        8425.0         0.0
# ...             ...        ...                 ...           ...         ...
# 999995        814.0       34.0              46.429          27.0         5.0
# 999996         39.0        0.0               5.429           0.0         0.0
# 999997      37419.0        0.0               4.714         833.0         0.0
# 999998     913371.0     1369.0            1066.714        5969.0         4.0
# 999999       6123.0        0.0               0.429          76.0         0.0
#
#         new_deaths_smoothed  ...  handwashing_facilities  \
# 0                    69.143  ...                   0.000
# 1                     0.000  ...                   0.000
# 2                     2.286  ...                   0.000
# 3                     0.000  ...                  22.863
# 4                     1.857  ...                   0.000
# ...                     ...  ...                     ...
# 999995                2.429  ...                   0.000
# 999996                0.000  ...                   0.000
# 999997                0.000  ...                   0.000
# 999998                1.714  ...                   0.000
# 999999                0.000  ...                  41.340
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             7.02            76.88                    0.854
# 1                             6.56            75.93                    0.882
# 2                             4.69            78.74                    0.892
# 3                             0.70            64.00                    0.510
# 4                             2.30            78.51                    0.815
# ...                            ...              ...                      ...
# 999995                       13.05            84.63                    0.919
# 999996                        0.00            83.73                    0.868
# 999997                        2.90            73.92                    0.814
# 999998                        5.57            75.29                    0.866
# 999999                        2.90            70.39                    0.625
#
#          population  excess_mortality_cumulative_absolute  \
# 0         9967304.0                                 0.000
# 1         2750058.0                                 0.000
# 2         1326064.0                              4739.699
# 3        11585003.0                                 0.000
# 4         4408582.0                                 0.000
# ...             ...                                   ...
# 999995  123951696.0                                 0.000
# 999996      79843.0                                 0.000
# 999997     409989.0                                 0.000
# 999998    1850654.0                                 0.000
# 999999     227393.0                                 0.000
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                              0.00              0.00
# 1                              0.00              0.00
# 2                             10.03             30.86
# 3                              0.00              0.00
# 4                              0.00              0.00
# ...                             ...               ...
# 999995                         0.00              0.00
# 999996                         0.00              0.00
# 999997                         0.00              0.00
# 999998                         0.00              0.00
# 999999                         0.00              0.00
#
#         excess_mortality_cumulative_per_million  Sample Number
# 0                                        0.0000              0
# 1                                        0.0000              1
# 2                                     3583.1782              2
# 3                                        0.0000              3
# 4                                        0.0000              4
# ...                                         ...            ...
# 999995                                   0.0000         999995
# 999996                                   0.0000         999996
# 999997                                   0.0000         999997
# 999998                                   0.0000         999998
# 999999                                   0.0000         999999
#
# [1000000 rows x 68 columns]

# %% [markdown]
# #### 1.2 Write to disk

# %%
# write to csv
df.to_csv("../data/covid-data.csv")

# %%
# write to parquet
df.to_parquet("../data/covid-data.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # write to parquet
# ----> 2 df.to_parquet("../data/covid-data.parquet")
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pandas\core\frame.py:2889, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2802 """
#    2803 Write a DataFrame to the binary parquet format.
#    2804
#    (...)
#    2885 >>> content = f.read()
#    2886 """
#    2887 from pandas.io.parquet import to_parquet
# -> 2889 return to_parquet(
#    2890     self,
#    2891     path,
#    2892     engine,
#    2893     compression=compression,
#    2894     index=index,
#    2895     partition_cols=partition_cols,
#    2896     storage_options=storage_options,
#    2897     **kwargs,
#    2898 )
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pandas\io\parquet.py:411, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     407 impl = get_engine(engine)
#     409 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 411 impl.write(
#     412     df,
#     413     path_or_buf,
#     414     compression=compression,
#     415     index=index,
#     416     partition_cols=partition_cols,
#     417     storage_options=storage_options,
#     418     **kwargs,
#     419 )
#     421 if path is None:
#     422     assert isinstance(path_or_buf, io.BytesIO)
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pandas\io\parquet.py:159, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, **kwargs)
#     156 if index is not None:
#     157     from_pandas_kwargs["preserve_index"] = index
# --> 159 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     161 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     162     path,
#     163     kwargs.pop("filesystem", None),
#    (...)
#     166     is_dir=partition_cols is not None,
#     167 )
#     168 if (
#     169     isinstance(path_or_handle, io.BufferedWriter)
#     170     and hasattr(path_or_handle, "name")
#     171     and isinstance(path_or_handle.name, (str, bytes))
#     172 ):
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pyarrow\table.pxi:3681, in pyarrow.lib.Table.from_pandas()
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pyarrow\pandas_compat.py:624, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     622     for i, maybe_fut in enumerate(arrays):
#     623         if isinstance(maybe_fut, futures.Future):
# --> 624             arrays[i] = maybe_fut.result()
#     626 types = [x.type for x in arrays]
#     628 if schema is None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pyarrow\pandas_compat.py:598, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
# --> 598     raise e
#     599 if not field_nullable and result.null_count > 0:
#     600     raise ValueError("Field {} was non-nullable but pandas column "
#     601                      "had {} null values".format(str(field),
#     602                                                  result.null_count))
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pyarrow\pandas_compat.py:592, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     589     type_ = field.type
#     591 try:
# --> 592     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pyarrow\array.pxi:323, in pyarrow.lib.array()
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pyarrow\array.pxi:83, in pyarrow.lib._ndarray_to_array()
#
# File c:\Users\Raj\repos\hf-nlp\.venv\Lib\site-packages\pyarrow\error.pxi:123, in pyarrow.lib.check_status()
#
# ArrowTypeError: ("Expected bytes, got a 'int' object", 'Conversion failed for column continent with type object')
